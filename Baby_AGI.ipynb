# %%
# !pip install langchain==0.0.208
# Out:
# ...
#   Obtaining dependency information for langchain==0.0.208 from https://files.pythonhosted.org/packages/9e/1c/ec4295280a03d4db857650787324287b67d41990551beafbeb71c79f6bdf/langchain-0.0.208-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for PyYAML>=5.4.1 from https://files.pythonhosted.org/packages/2b/9f/fbade56564ad486809c27b322d0f7e6a89c01f6b4fe208402e90d4443a99/PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# ...
#   Obtaining dependency information for SQLAlchemy<3,>=1.4 from https://files.pythonhosted.org/packages/eb/d5/bd96a7fbb6a7cbc363b1f7f740626902676846b559305a06c222054d222a/SQLAlchemy-2.0.21-cp312-cp312-win_amd64.whl.metadata
#   Using cached SQLAlchemy-2.0.21-cp312-cp312-win_amd64.whl.metadata (9.7 kB)
# ...
#   Using cached aiohttp-3.8.6.tar.gz (7.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
# ...

# %%
import langchain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\veace\Desktop\Langchain_S\Baby_AGI.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/veace/Desktop/Langchain_S/Baby_AGI.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import langchain
#
# ModuleNotFoundError: No module named 'langchain'
